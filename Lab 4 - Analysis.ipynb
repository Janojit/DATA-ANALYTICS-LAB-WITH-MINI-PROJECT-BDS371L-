# %% [markdown]
# # Lab 4 - Analysis
# ## Coder Name: Janojit Chakraborty
# ## Coder Registration Number: 21112011

# %% [markdown]
# ### Objective
# - Exploratory Data Analysis of Previously generated Dataset

# %% [markdown]
# ### Problem Definition

# %% [markdown]
# An analysis on the Synthetic Dataset that I have created and upload the result, based on the basic methods available in Pandas. Additional Exploration: Plotting through Matplotlib / Seaborn

# %% [markdown]
# ### Approach/Methods
# 1. First importing the necessary libraries ( *pandas,Seaborn*)
# 1. Using different plots from the seaborn library to perform visual analysis on the created dataset.
#     1. Histplot
#     1. Countplot
#     1. Stripplot
#     1. Boxplot
#     1. displot
#     1. Catplot
#     1. Pairgrid
#     1. Pairplot
#     1. Heatmap

# %% [markdown]
# ### Observation:
#
# - From displot of Age, we observed that most of the employees age is 60. So the organization needs to hire more freshers as most of the employees going to retire.
# - From the displot of Working Hour, we observed that most of employees are working for 5 to 6 hours, which may caused low productivity as a whole organization that's need to focused.
# - From the displot of Typing speed, we can conclude that the organization doesn't focuses much on Typing Speed while hiring employees.
# - From the count plot of Gender, we observed that most of the employees of this organization are Male. So, maybe the previous hiring process was biased against Females and Others.
# - From the count plot of Loan, we observed that most the employees are without any loan. It is a good sign for the organization as it indicates most of the employees are getting their actual wage.
# - From the catplot of Gender and Age, we observed that median age of females are higher as compare to males and others. Now we previously seen that number of female is also less and a huge number of employees are going to retire. So there is a huge probability that a large set of female employees are going to retire. From which we can suggest that the organization should recruit more numbers of female freshers.
# - From boxplot of Gender and Salary, we observed that most of the males are getting more salaries as compare to females and others. We have previously seen that already the hiring process of this organization is biased against females and others now we also observed the biasness in terms of salary also. Organization needs to focus on this issue as it depicts negativity towards the organization.
# - From the barplot of Working Hour and Salary, we observed those who are working less hours are getting more salaries, which is unusual. Maybe less hours employees are more efficient thats why they needs less time to complete a task and that's the reason they are getting more salaries.
# - From the bar plot of Loan and salary, we observed that employees who are under loan are getting enough salary. It is a good sign for the organization as it indicates most of the employees are getting their actual wage.
# - From the strip plot of Loan and salary, we observed that employees who are under loan are male. As we also observed males are getting higher salary maybe that is the reason they are taking more loans.
# - Heatmap shows the correlation between all numeric attributes.

# %% [markdown]
# ### Results:
# - From the Data Exploration we get basic understanding about the dataset.
# - We are able to fetch unique insights about the dataset.
# - We are able to locate some loophole about the dataset.

# %% [markdown]
# ### Learnings & Reflection:
# - Understanding different visualizations technique.
# - Get to know about different features of Seaborn library.
# - Get idea about Exploratory Data Analysis.
# - Get a basic introduction about Data Story Telling.

# %% [markdown]
# Name: **Janojit Chakraborty** <br>
# Reg No: **21112011** <br>
# Class: **3 BSC DS** <br>
#
# ---------------
#
#
# | Assignment | Status |
# | --- | --- |
# |   | __Completed__ |

# %% [markdown]
# <br>

# %% [markdown]
# # Code:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("export_dataframe.csv")
df
# Out:
#       Employee ID  Age  Working Hour  Typing Speed Loan Gender  Salary
# 0          223540   27             9            57   No      F  956725
# 1          524626   21             6            31   No      O   72255
# 2          730043   53             9            71   No      F  487332
# 3          269047   53             9           101  Yes      M  981336
# 4          297372   42             7            40   No      F  204563
# ...           ...  ...           ...           ...  ...    ...     ...
# 1995       671601   48             8            68   No      F  243074
# 1996       803037   52             9            91   No      F  466482
# 1997       659271   49             9            59   No      F  776896
# 1998       172428   43             8           113   No      F  179537
# 1999       663689   32             6            97  Yes      M  786562
#
# [2000 rows x 7 columns]

# %%
df.describe()
# Out:
#          Employee ID          Age  Working Hour  Typing Speed        Salary
# count    2000.000000  2000.000000   2000.000000   2000.000000  2.000000e+03
# mean   544854.626500    40.306000      6.954500     74.387000  5.280203e+05
# std    262127.321324    11.837839      1.415073     26.752366  2.816040e+05
# min    100734.000000    20.000000      5.000000     30.000000  5.527400e+04
# 25%    316307.750000    30.000000      6.000000     52.000000  2.836252e+05
# 50%    542766.500000    41.000000      7.000000     73.500000  5.279900e+05
# 75%    769288.250000    51.000000      8.000000     98.000000  7.754215e+05
# max    999732.000000    60.000000      9.000000    120.000000  1.004292e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Employee ID   2000 non-null   int64
#  1   Age           2000 non-null   int64
#  2   Working Hour  2000 non-null   int64
#  3   Typing Speed  2000 non-null   int64
#  4   Loan          2000 non-null   object
#  5   Gender        2000 non-null   object
#  6   Salary        2000 non-null   int64
# dtypes: int64(5), object(2)
# memory usage: 109.5+ KB

# %%
sns.set(style='whitegrid', palette="deep", font_scale=1.1, rc={"figure.figsize": [8, 5]})
sns.distplot(
    df['Age'], norm_hist=False, kde=False, bins=20, hist_kws={"alpha": 1}
).set(xlabel='Age', ylabel='Count');
# Out:
# C:\Users\janoj\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Obsevation:
# From displot of Age, we observed that most of the employees age is 60. So the organization needs to hire more freshers as most of the employees going to retire.

# %%
sns.set(style='whitegrid', palette="deep", font_scale=1.1, rc={"figure.figsize": [8, 5]})
sns.distplot(
    df['Working Hour'], norm_hist=False, kde=False, bins=20, hist_kws={"alpha": 1}
).set(xlabel='Working Hour', ylabel='Count');

# %% [markdown]
# ### Observation:
# From the displot of Working Hour, we observed that most of employees are working for 5 to 6 hours, which may caused low productivity as a whole organization that's need to focused.

# %%
sns.set(style='whitegrid', palette="deep", font_scale=1.1, rc={"figure.figsize": [8, 5]})
sns.distplot(
    df['Typing Speed'], norm_hist=False, kde=False, bins=20, hist_kws={"alpha": 1}
).set(xlabel='Typing Speed', ylabel='Count');

# %% [markdown]
# ### Observation:
# From the displot of Typing speed, we can conclude that the organization doesn't focuses much on Typing Speed while hiring employees.

# %%
sns.countplot(df['Gender']);
# Out:
# C:\Users\janoj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Observation:
# From the count plot of Gender, we observed that most of the employees of this organization are Male. So, maybe the previous hiring process was biased against Females and Others.

# %%
sns.countplot(df['Loan']);
# Out:
# C:\Users\janoj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Observation:
# From the count plot of Loan, we observed that most the employees are without any loan. It is a good sign for the organization as it indicates most of the employees are getting their actual wage.

# %%
ax = sns.catplot(x="Gender", y="Age", kind="violin",
                 split=True, palette="pastel", data=df, height=4.2, aspect=1.4)

# %% [markdown]
# ### Observation:
# From the catplot of Gender and Age, we observed that median age of females are higher as compare to males and others. Now we previously seen that number of female is also less and a huge number of employees are going to retire. So there is a huge probability that a large set of female employees are going to retire. From which we can suggest that the organization should recruit more numbers of female freshers.

# %%
sns.catplot(x="Gender", y="Salary", kind="box", data=df, height=4.2, aspect=1.4)

# %% [markdown]
# ### Observation:
# From boxplot of Gender and Salary, we observed that most of the males are getting more salaries as compare to females and others. We have previously seen that already the hiring process of this organization is biased against females and others now we also observed the biasness in terms of salary also. Organization needs to focus on this issue as it depicts negativity towards the organization.

# %%
sns.scatterplot(x=df['Typing Speed'], y=df['Salary']);

# %%
sns.jointplot(x=df['Working Hour'], y=df['Salary']);

# %%
sns.barplot(df["Working Hour"],df["Salary"])
# Out:
# C:\Users\janoj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Working Hour', ylabel='Salary'>

# %% [markdown]
# ### Observation:
# From the barplot of Working Hour and Salary, we observed those who are working less hours are getting more salaries, which is unusual. Maybe less hours employees are more efficient thats why they needs less time to complete a task and that's the reason they are getting more salaries.

# %%
sns.barplot(df["Loan"],df["Salary"])
# Out:
# C:\Users\janoj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Loan', ylabel='Salary'>

# %% [markdown]
# ### Observation:
# From the bar plot of Loan and salary, we observed that employees who are under loan are getting enough salary. It is a good sign for the organization as it indicates most of the employees are getting their actual wage.

# %%
sns.stripplot(x ='Loan', y ='Gender', data = df,
              jitter = True, dodge = True)
# Out:
# <AxesSubplot:xlabel='Loan', ylabel='Gender'>

# %% [markdown]
# ### Observation:
# From the strip plot of Loan and salary, we observed that employees who are under loan are male. As we also observed males are getting higher salary maybe that is the reason they are taking more loans.

# %%
g = sns.PairGrid(df, y_vars=["Loan"], x_vars=["Age", "Salary"], height=4.5, aspect=1.1)
g.map(plt.scatter, alpha=0.6)

# %%
sns.pairplot(data = df, vars=['Loan','Gender','Salary','Age','Working Hour','Typing Speed'])
plt.show()

# %%
df1 = df[['Age','Working Hour','Typing Speed','Salary']].corr()

df1.corr()

sns.heatmap(df1.corr(), annot=True, cmap = 'Reds')
plt.show()

# %% [markdown]
# ### Observation:
# Heatmap shows the correlation between all numeric attributes.
